# %%
from funcs.model import aflare_decoupled

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/ekaterina/Documents/000_envs/forallpurposes/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# NumExpr defaulting to 8 threads.

# %%
time = np.linspace(10, 20, 3200)

# %%
tpeak = 12.
a = 1.
plt.figure(figsize=(8,5))
for rise in np.linspace(1e-2,.05,3):
    for dec in np.linspace(1e-2,.5, 3):
        plt.plot(time, aflare_decoupled(time, tpeak, (rise, dec) , a,)+1)
plt.yscale("log")
plt.xscale("log")
