# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

#from altaipony.fakeflares import aflare

import os
CWD = "/".join(os.getcwd().split("/")[:-2])

import pytest

from funcs.model import (daylength, 
                         on_off, 
                         full_model, 
                         lambert, 
                         dot_ensemble_circular, 
                         lightcurve_model, 
                         aflare,
                         aflare_decoupled)

import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 
matplotlib.rc('xtick.major', size=10, pad=7)

import astropy.units as u
from astropy.constants import R_sun

# %% [markdown]
# ### Plots

# %%
# plot a grid

#latitudes, longitudes = dot_ensemble(np.pi/2-np.pi/8,np.pi/2-np.pi/10,4,num_pts=1e6)
latitudes, longitudes, pos = dot_ensemble_circular(60/180*np.pi,0,3,num_pts=300)
plt.figure(figsize=(8,8))
plt.scatter(longitudes/np.pi*180, latitudes/np.pi*180)
#plt.scatter([180/2-180/10],[180/2-180/8],)
plt.xlabel("longitude [deg]")
plt.ylabel("latitude [deg]")
#plt.savefig(f"{CWD}/analysis/plots/model/dot_ensemble.png",dpi=300)
latitudes[:3]
# Out:
# array([1.0464188 , 1.05051848, 1.04260257])

# %%
# Plot a model consisting of an ensemble of rotating flaring points on a sphere

I = 40 * np.pi / 180.
phi = np.linspace(-2*np.pi,14*np.pi,3000)
flares = []
#for i in np.linspace(2.5,3.5,20):
#    flares.append( aflare(phi, i, 2.44, 5,))
fig = plt.figure(figsize=(9,5.5))

ax = fig.add_subplot(111)
ax2 = ax.twiny()


#set ticks
T=[1,2,3]
ax.set_yticks(T)

#set labels
labels=[1,2,3]
ax.set_yticklabels(labels)


#set ticks
T=[0,0.25,0.625,1.125]
ax2.set_xticks(T, )

#set labels
labels=[r"$t_0$",r"$t_f$", r"$t_{min}$",r"$t_{max}$"]
ax2.set_xticklabels(labels, fontsize=25)

#set ticks
T=[-1,0,1,2,3,4,5,]
ax.set_xticks(T, )

#set labels
labels=[-1,0,1,2,3,4,5]
ax.set_xticklabels(labels, fontsize=20)

phia,  a,  fwhm1, fwhm2 = np.pi*0.5, 2., .8, 1.7
flare = aflare_decoupled(phi, phia, (fwhm1,fwhm2), a )

lamb, onoff, m = lightcurve_model(phi, latitudes, longitudes, flare, I, phi0=0)

# for l,oo in zip(lamb,onoff):
#     plt.plot(phi/2/np.pi, l*oo*flare + 1, alpha=.1, c="grey")
#for f in flares:
#    lamb, onoff, m = model(phi, latitudes, longitudes, f, I)
#    plt.plot(phi/2/np.pi,m+1,c="k",linewidth=.1,)# label="model light curve")#,\naverage of individual\ngrid dots (in grey)")
plt.plot(phi/2/np.pi,m+1,c="r",linewidth=4, label="model light curve")#,\naverage of individual\ngrid dots (in grey)")

plt.plot(phi/2/np.pi,flare+1, label="underlying flare",c="grey",linestyle="dashed",linewidth=4)
ax.set_xlabel("time [rotation periods]",fontsize=20)

plt.ylabel("relative flux",fontsize=20)
plt.xlim(-1,5)
plt.legend(fontsize=20, frameon=False)
#plt.yscale("log")
plt.tight_layout()
plt.ylim(.9,3)
#plt.savefig(f"{CWD}/analysis/plots/ddt/lightcurve_l70_i71_linear2.png",dpi=300);
# Out:
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2580         try:
# -> 2581             result = self._expression.parseString(s)
#    2582         except ParseBaseException as err:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4051             else:
# -> 4052                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4053             if exprtokens or exprtokens.haskeys():
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4763         try:
# -> 4764             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4765         except (ParseException, IndexError):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4034         # pre-parsed the string as part of our And pre-parsing
# -> 4035         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4036         errorStop = False
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2655     def math_string(self, s, loc, toks):
# -> 2656         return self._math_expression.parseString(toks[0][1:-1])
#    2657
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4236             try:
# -> 4237                 ret = e._parse(instring, loc, doActions)
#    4238                 return ret
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in unknown_symbol(self, s, loc, toks)
#    2751         c = toks[0]
# -> 2752         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2753
#
# ParseFatalException: Unknown symbol: \mathbf, found '\'  (at char 0), (line:1, col:1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-93b5b7a0b728> in <module>
#      56 plt.legend(fontsize=20, frameon=False)
#      57 #plt.yscale("log")
# ---> 58 plt.tight_layout()
#      59 plt.ylim(.9,3)
#      60 #plt.savefig(f"{CWD}/analysis/plots/ddt/lightcurve_l70_i71_linear2.png",dpi=300);
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1335         labels) will fit into. Default is (0, 0, 1, 1).
#    1336     """
# -> 1337     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1338
#    1339
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2491         kwargs = get_tight_layout_figure(
#    2492             self, self.axes, subplotspec_list, renderer,
# -> 2493             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2494         if kwargs:
#    2495             self.subplots_adjust(**kwargs)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     358                                      subplot_list=subplot_list,
#     359                                      ax_bbox_list=ax_bbox_list,
# --> 360                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     361
#     362     # kwargs can be none if tight_layout fails...
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     107             continue
#     108
# --> 109         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     110                                 if ax.get_visible()])
#     111         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     108
#     109         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 110                                 if ax.get_visible()])
#     111         tight_bbox = TransformedBbox(tight_bbox_raw,
#     112                                      fig.transFigure.inverted())
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4323                 bb.append(bb_yaxis)
#    4324
# -> 4325         self._update_title_position(renderer)
#    4326         axbbox = self.get_window_extent(renderer)
#    4327         bb.append(axbbox)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2531                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2532                         or ax.xaxis.get_label_position() == 'top'):
# -> 2533                     bb = ax.xaxis.get_tightbbox(renderer)
#    2534                 else:
#    2535                     bb = ax.get_window_extent(renderer)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1186         ticks_to_draw = self._update_ticks()
#    1187
# -> 1188         self._update_label_position(renderer)
#    1189
#    1190         # go back to just this axis's tick labels
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2005             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#    2008             bboxes2.extend(tlb2)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
# -> 1176                  for tick in ticks if tick.label2.get_visible()])
#    1177
#    1178     def get_tightbbox(self, renderer):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
# -> 1176                  for tick in ticks if tick.label2.get_visible()])
#    1177
#    1178     def get_tightbbox(self, renderer):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     298             if clean_line:
#     299                 w, h, d = renderer.get_text_width_height_descent(
# --> 300                     clean_line, self._fontproperties, ismath=ismath)
#     301             else:
#     302                 w = h = d = 0
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207         if ismath:
#     208             ox, oy, width, height, descent, fonts, used_characters = \
# --> 209                 self.mathtext_parser.parse(s, self.dpi, prop)
#     210             return width, height, descent
#     211
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3352             self.__class__._parser = Parser()
#    3353
# -> 3354         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3355         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3356         return font_output.get_results(box)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2584                                         err.line,
#    2585                                         " " * (err.column - 1) + "^",
# -> 2586                                         str(err)]))
#    2587         self._state_stack = None
#    2588         self._em_width_cache = {}
#
# ValueError:
# \mathbf\mathit{{t_f}}
# ^
# Unknown symbol: \mathbf, found '\'  (at char 0), (line:1, col:1)
# ---------------------------------------------------------------------------
# ParseFatalException                       Traceback (most recent call last)
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2580         try:
# -> 2581             result = self._expression.parseString(s)
#    2582         except ParseBaseException as err:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4051             else:
# -> 4052                 loc, exprtokens = e._parse(instring, loc, doActions)
#    4053             if exprtokens or exprtokens.haskeys():
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4763         try:
# -> 4764             return super(ZeroOrMore, self).parseImpl(instring, loc, doActions)
#    4765         except (ParseException, IndexError):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4034         # pre-parsed the string as part of our And pre-parsing
# -> 4035         loc, resultlist = self.exprs[0]._parse(instring, loc, doActions, callPreParse=False)
#    4036         errorStop = False
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in math_string(self, s, loc, toks)
#    2655     def math_string(self, s, loc, toks):
# -> 2656         return self._math_expression.parseString(toks[0][1:-1])
#    2657
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1946                 # catch and re-raise exception from here, clears out pyparsing internal stack trace
# -> 1947                 raise exc
#    1948         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseString(self, instring, parseAll)
#    1936         try:
# -> 1937             loc, tokens = self._parse(instring, 0)
#    1938             if parseAll:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4679             try_not_ender(instring, loc)
# -> 4680         loc, tokens = self_expr_parse(instring, loc, doActions, callPreParse=False)
#    4681         try:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4444         if self.expr is not None:
# -> 4445             return self.expr._parse(instring, loc, doActions, callPreParse=False)
#    4446         else:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1676                 try:
# -> 1677                     loc, tokens = self.parseImpl(instring, preloc, doActions)
#    1678                 except IndexError:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in parseImpl(self, instring, loc, doActions)
#    4236             try:
# -> 4237                 ret = e._parse(instring, loc, doActions)
#    4238                 return ret
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseCache(self, instring, loc, doActions, callPreParse)
#    1837                 try:
# -> 1838                     value = self._parseNoCache(instring, loc, doActions, callPreParse)
#    1839                 except ParseBaseException as pe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in _parseNoCache(self, instring, loc, doActions, callPreParse)
#    1709                     try:
# -> 1710                         tokens = fn(instring, tokensStart, retTokens)
#    1711                     except IndexError as parse_action_exc:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/pyparsing.py in wrapper(*args)
#    1315             try:
# -> 1316                 ret = func(*args[limit[0]:])
#    1317                 foundArity[0] = True
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in unknown_symbol(self, s, loc, toks)
#    2751         c = toks[0]
# -> 2752         raise ParseFatalException(s, loc, "Unknown symbol: %s" % c)
#    2753
#
# ParseFatalException: Unknown symbol: \mathbf, found '\'  (at char 0), (line:1, col:1)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2065                         functools.partial(
#    2066                             print_method, dpi=dpi, orientation=orientation))
# -> 2067                     self.figure.draw(renderer)
#    2068                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2069                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2588                 artists.remove(spine)
#    2589
# -> 2590         self._update_title_position(renderer)
#    2591
#    2592         if not self.axison or inframe:
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2531                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2532                         or ax.xaxis.get_label_position() == 'top'):
# -> 2533                     bb = ax.xaxis.get_tightbbox(renderer)
#    2534                 else:
#    2535                     bb = ax.get_window_extent(renderer)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1186         ticks_to_draw = self._update_ticks()
#    1187
# -> 1188         self._update_label_position(renderer)
#    1189
#    1190         # go back to just this axis's tick labels
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2005             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#    2008             bboxes2.extend(tlb2)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
# -> 1176                  for tick in ticks if tick.label2.get_visible()])
#    1177
#    1178     def get_tightbbox(self, renderer):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
# -> 1176                  for tick in ticks if tick.label2.get_visible()])
#    1177
#    1178     def get_tightbbox(self, renderer):
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     298             if clean_line:
#     299                 w, h, d = renderer.get_text_width_height_descent(
# --> 300                     clean_line, self._fontproperties, ismath=ismath)
#     301             else:
#     302                 w = h = d = 0
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207         if ismath:
#     208             ox, oy, width, height, descent, fonts, used_characters = \
# --> 209                 self.mathtext_parser.parse(s, self.dpi, prop)
#     210             return width, height, descent
#     211
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, dpi, prop)
#    3352             self.__class__._parser = Parser()
#    3353
# -> 3354         box = self._parser.parse(s, font_output, fontsize, dpi)
#    3355         font_output.set_canvas_size(box.width, box.height, box.depth)
#    3356         return font_output.get_results(box)
#
# ~/Documents/000_envs/forallpurposes/lib/python3.6/site-packages/matplotlib/mathtext.py in parse(self, s, fonts_object, fontsize, dpi)
#    2584                                         err.line,
#    2585                                         " " * (err.column - 1) + "^",
# -> 2586                                         str(err)]))
#    2587         self._state_stack = None
#    2588         self._em_width_cache = {}
#
# ValueError:
# \mathbf\mathit{{t_f}}
# ^
# Unknown symbol: \mathbf, found '\'  (at char 0), (line:1, col:1)

# %%
phi = np.linspace(0,6*np.pi,2000)
phia,  a,  fwhm = 1.55, 26, 2.5
flare = aflare(phi, phia, fwhm, a )
plt.figure(figsize=(9,4))
for (lat,i,c) in [(25,27,"green"),(69,71,"orange")]:
    latitudes, longitudes, pos = dot_ensemble_circular(lat/180*np.pi,0,3,num_pts=300)
    I = i * np.pi / 180.
    #lamb, onoff, m = full_model(phi, latitudes, longitudes, flare, I)
    

    lamb, onoff, m = lightcurve_model(phi, latitudes, longitudes, flare, I, phi0=0)
    plt.plot(phi/2/np.pi,m+1,c=c,linewidth=3, 
             label=f"model light curve")#,\naverage of individual\ngrid dots (in grey)")
    
plt.plot(phi/2/np.pi,flare+1, label="underlying flare",c="r",linestyle="dashed",linewidth=3)
plt.xlabel("time [rotation periods]",fontsize=15)
plt.ylabel("rel. flux",fontsize=15)
plt.xlim(0,3)
plt.legend(fontsize=13)
#plt.yscale("log")
plt.tight_layout()
#plt.ylim(0,6)
#plt.savefig(f"{CWD}/analysis/plots/ddt/lightcurve_both_salt.png",dpi=300);
