# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import os
CWD = "/".join(os.getcwd().split("/")[:-2])

from funcs.model import (daylength,
                         on_off,
                         lambert,
                         great_circle_distance,
                         dot_ensemble_circular,
                         FlareModulator,
                         lightcurve_model,
                         aflare)

from funcs.helper import no_nan_inf
import matplotlib 
matplotlib.rc('xtick', labelsize=20) 
matplotlib.rc('ytick', labelsize=20) 

from mpl_toolkits.mplot3d import Axes3D
# Out:
# /home/ekaterina/Documents/000_envs/forallpurposes/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# NumExpr defaulting to 8 threads.

# %%
df = pd.read_csv(f"{CWD}/analysis/results/mcmc/15_12_2020_GP_mcmcoutput.csv")
row = df.iloc[4]
row
# Out:
# ED_s_16                     2399.68
# ED_s_50                     2433.25
# ED_s_84                     2466.29
# Eflare_erg_16           2.23373e+33
# Eflare_erg_50           2.26498e+33
# Eflare_erg_84           2.29573e+33
# ID                         44984200
# a_16                       0.493929
# a_50                       0.504206
# a_84                       0.514489
# color                       #4daf4a
# frac_area_16              0.0041346
# frac_area_50             0.00422099
# frac_area_84             0.00430745
# fwhm1_d_16                 0.008475
# fwhm1_d_50                0.0100631
# fwhm1_d_84                0.0110124
# fwhm2_d_16                0.0439071
# fwhm2_d_50                0.0446187
# fwhm2_d_84                0.0453561
# i_deg_16                    32.2391
# i_deg_50                    33.0936
# i_deg_84                    33.9438
# latitude_deg_16             70.7606
# latitude_deg_50             71.8553
# latitude_deg_84             72.9512
# linestyle                    dashed
# phase_deg_16                253.732
# phase_deg_50                257.655
# phase_deg_84                261.566
# rad_rsun_16                 7.37342
# rad_rsun_50                 7.45016
# rad_rsun_84                 7.52619
# suffix                            a
# t0_d_16                     1588.01
# t0_d_50                     1588.01
# t0_d_84                     1588.01
# tstamp             10_12_2020_07_10
# Name: 4, dtype: object

# %%
def xyz(theta, phi):
    "convert spherical coordinates to cartesian"
    return np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi)

# %matplotlib inline

# %% [markdown]
# # plot a grid

# %%
latdeg = row.latitude_deg_50
londeg = row.phase_deg_50

latitudes, longitudes, pos = dot_ensemble_circular(latdeg/180*np.pi,londeg/180*np.pi,radius,num_pts=100)
plt.figure(figsize=(8,8))
plt.scatter(longitudes/np.pi*180, latitudes/np.pi*180)
plt.xlabel("longitude [deg]")
plt.ylabel("latitude [deg]");

#plt.savefig(f"{CWD}/analysis/plots/model/dot_ensemble.png",dpi=300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9b265a96c9e2> in <module>
#       2 londeg = row.phase_deg_50
#       3
# ----> 4 latitudes, longitudes, pos = dot_ensemble_circular(latdeg/180*np.pi,londeg/180*np.pi,radius,num_pts=100)
#       5 plt.figure(figsize=(8,8))
#       6 plt.scatter(longitudes/np.pi*180, latitudes/np.pi*180)
#
# NameError: name 'radius' is not defined

# %% [markdown]
# # Plot a model consisting of an ensemble of rotating flaring points on a sphere

# %%
latdeg = row.latitude_deg_50#30 # latitude in deg
rotation = londeg*np.pi/180#45.*np.pi/180 #peak time of flare
incdeg = row.i_deg_50 # inclination in deg
I = incdeg * np.pi / 180. # inclination in rad
phi = np.linspace(0,4*np.pi,2000) #time
ampl = row.a_50 # amplitude
fwhm = row.fwhm1_d_50 # FWHM
flare = aflare(phi, rotation, fwhm, ampl,) # underlying flare

# model light curve, esp. lambert factor and visibility:
lamb, onoff, m = lightcurve_model(phi, latitudes, longitudes, flare, I)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7272660e8f05> in <module>
#       9
#      10 # model light curve, esp. lambert factor and visibility:
# ---> 11 lamb, onoff, m = lightcurve_model(phi, latitudes, longitudes, flare, I)
#
# NameError: name 'latitudes' is not defined

# %%
l=100 # resolution of lines to draw on the sphere
percent = row.frac_area_50*100 # fractional area of flaring area
num_pts = 1e5 # total number of grid points on the sphere
indices = np.arange(0, num_pts, dtype=float) + 0.5 
d = daylength(latdeg / 180*np.pi,i=I) # length of day at latitude latdeg when viewed at inclination I


phi = np.arccos(1 - 2*indices/num_pts) #latitudes of the grid
theta = np.pi * (1 + 5**0.5) * indices  #longitudes of the grid

# select grid points and convert from spherical to cartesian coordinates
a = np.where(great_circle_distance(latdeg/180*np.pi,
                                   rotation*np.pi/180, 
                                   np.pi/2 - phi%(2*np.pi), 
                                   theta%(np.pi*2)) < (percent/180*np.pi))[0]
phi2 = phi[a]
theta2 = theta[a]
x, y, z = np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi);
x2, y2, z2 = np.cos(theta2) * np.sin(phi2), np.sin(theta2) * np.sin(phi2), np.cos(phi2);

# Plot it!

fig=plt.figure(figsize=(12.4,12.5))
ax=fig.add_subplot(1,1,1,projection="3d")
ax.scatter(x, y, z, s=.05, alpha=.5);
ax.scatter(x2, y2, z2, s=25.5, c="r", label="active region");

# active latitude

d = daylength(latdeg/180*np.pi,i=I)
phi = np.full(l,np.pi/2-latdeg*np.pi/180)
theta = np.linspace(-d*np.pi + rotation,d*np.pi + rotation,l)
xtheta, ytheta, ztheta = xyz(theta, phi)
ax.plot(xtheta, ytheta, ztheta, linewidth=1.5, c="r",label=r"$\theta$");

# equator

d = daylength(0,i=I)
phi = np.full(l,np.pi/2-0.01)
theta = np.linspace(-d*np.pi + rotation, d*np.pi + rotation,l)
xtheta, ytheta, ztheta = xyz(theta, phi)
ax.plot(xtheta, ytheta, ztheta, linewidth=1.5, c="grey", label="equator");

# rotational pole

ax.scatter([0,],[0,],[1.,],s=300,c="k",marker="*",label="rotational pole")

# line of sight

# theta, phi = [ rotation], [incdeg*np.pi/180]
# x, y, z = xyz(theta, phi)
# ax.scatter(x,y,z,s=200,c="k",marker="x", label="line of sight")

# solar upper limit
latdeg=30
d = daylength(latdeg/180*np.pi,i=I)
phi = np.full(l,np.pi/2-latdeg*np.pi/180)
theta = np.linspace(-d*np.pi + rotation,d*np.pi + rotation,l)
xtheta, ytheta, ztheta = xyz(theta, phi)
# ax.plot(xtheta, ytheta, ztheta, linewidth=3.5, c="orange",linestyle="dashed", label=r"$\theta$");

# layout

# plt.legend(fontsize=16, loc=(0.1,0.75),frameon=False)
plt.axis('off')
# ax.text(x=.5,y=0.5,z=1,s=f"TIC {str(row.ID)[:3]}",
#          horizontalalignment='center',
#          verticalalignment='center', 
#          transform=ax.transAxes)
ax.view_init(90-incdeg,  rotation*180/np.pi);

# plt.savefig(f"{CWD}/analysis/plots/flarefit/{row.ID}_spot_on_a_sphere_nosun.png",dpi=300)

# %%
def plot_star(fig,row,idx,kipp=0.):
    latdeg = row.latitude_deg_50#30 # latitude in deg
#     rotation = row.phase_deg_50*np.pi/180#45.*np.pi/180 #peak time of flare
    incdeg = np.abs(row.i_deg_50 - kipp) % 90. # inclination in deg
    I = incdeg * np.pi / 180. # inclination in rad
    l=100 # resolution of lines to draw on the sphere
    percent = row.frac_area_50*100 # fractional area of flaring area
    num_pts = 1e5 # total number of grid points on the sphere
    indices = np.arange(0, num_pts, dtype=float) + 0.5 
  
    rotation = row.phase_deg_50 * np.pi / 180
    d = daylength(latdeg / 180*np.pi,i=I) # length of day at latitude latdeg when viewed at inclination I


    phi = np.arccos(1 - 2*indices/num_pts) #latitudes of the grid
    theta = np.pi * (1 + 5**0.5) * indices  #longitudes of the grid

    # select grid points and convert from spherical to cartesian coordinates
    a = np.where(great_circle_distance(latdeg/180*np.pi,
                                       rotation*np.pi/180, 
                                       np.pi/2 - phi%(2*np.pi), 
                                       theta%(np.pi*2)) < (percent/180*np.pi))[0]
    phi2 = phi[a]
    theta2 = theta[a]
    
    x2, y2, z2 = np.cos(theta2) * np.sin(phi2), np.sin(theta2) * np.sin(phi2), np.cos(phi2);

    num_pts = 1e4 # total number of grid points on the sphere
    indices = np.arange(0, num_pts, dtype=float) + 0.5 
  
    phi = np.arccos(1 - 2*indices/num_pts) #latitudes of the grid
    theta = np.pi * (1 + 5**0.5) * indices  #longitudes of the grid

    x, y, z = np.cos(theta) * np.sin(phi), np.sin(theta) * np.sin(phi), np.cos(phi);
    # Plot it!

    
    ax=fig.add_subplot(2,2,idx,projection="3d")
    ax.patch.set_facecolor('blue')
    ax.patch.set_alpha(0.0)

    ax.scatter(x, y, z, s=.05, alpha=.5);
    ax.scatter(x2, y2, z2, s=25.5, c="r", label="active region");

    # active latitude

    d = daylength(latdeg/180*np.pi,i=I)
    phi = np.full(l,np.pi/2-latdeg*np.pi/180)
    theta = np.linspace(-d*np.pi + rotation,d*np.pi + rotation,l)
    xtheta, ytheta, ztheta = xyz(theta, phi)
    ax.plot(xtheta, ytheta, ztheta, linewidth=2, c="r",label=r"$\theta$");

    # equator

    d = daylength(0,i=I)
    phi = np.full(l,np.pi/2-0.01)
    theta = np.linspace(-d*np.pi + rotation, d*np.pi + rotation,l)
    xtheta, ytheta, ztheta = xyz(theta, phi)
    ax.plot(xtheta, ytheta, ztheta, linewidth=1.5, c="grey", label="equator");

    # rotational pole

    ax.scatter([0,],[0,],[1.,],s=100,c="k",marker="*",label="rotational pole")

    # line of sight

#     theta, phi = [ rotation], [incdeg*np.pi/180]
#     x, y, z = xyz(theta, phi)
#     ax.scatter(x,y,z,s=50,c="k",marker="x", label="line of sight")

    # solar upper limit
  
    d = daylength(30/180*np.pi,i=I)
    phi = np.full(l,np.pi/2-30*np.pi/180)
    theta = np.linspace(-d*np.pi + rotation,d*np.pi + rotation,l)
    xtheta, ytheta, ztheta = xyz(theta, phi)
    ax.plot(xtheta, ytheta, ztheta, linewidth=2, c="orange",linestyle="dashed", label=r"$\theta$");

    ax.view_init(90-incdeg,  rotation*180/np.pi);

# %%
fig=plt.figure(figsize=(14,14))
idx =1
for label, row in df.iloc[[1,0,4,2]].iterrows():
    if label == 1:
        kipp = 90.
    else:
        kipp = 0.
    plot_star(fig, row, idx, kipp=kipp)
    idx += 1
    plt.axis('off')
    
# ax.text(x=.5,y=0.5,z=1,s=f"TIC {str(row.ID)[:3]}",
#          horizontalalignment='center',
#          verticalalignment='center', 
#          transform=ax.transAxes)
plt.subplots_adjust(wspace=-0.35, hspace=-0.35)
plt.savefig(f"{CWD}/analysis/plots/flarefit/active_regions_four_stars_kipp.png",dpi=300)

# %%
phi = np.linspace(0,6*np.pi,2000)
plt.figure(figsize=(16,5))
plt.plot(phi/2/np.pi,flare+1, label="underlying flare",c="grey",linestyle="dotted",linewidth=8)
plt.plot(phi/2/np.pi,m+1,linewidth=4, label="model light curve", c="r")
plt.xlabel("time [rotation periods]",fontsize=20)
plt.ylabel("rel. flux",fontsize=20)
plt.xlim(0,3)
plt.legend(fontsize=20)
#plt.yscale("log")
plt.tight_layout()
#plt.title(f"Flare with rel. amplitude={ampl}, and FWHM={fwhm} rotation periods",fontsize=20)
# plt.savefig(f"{CWD}/analysis/plots/model/rotating_flare.png",dpi=300);

# %% [markdown]
# # plot a rotationally modulated single-dot-on-the-surface flare

# %%
flare = aflare(phi, 1.5, 1.3, 1,)
plt.figure(figsize=(8,16))
l = latdeg/180*np.pi
I = np.arange(30,91,10)/180*np.pi
for i in I:
    D = daylength(l,i)
    modulation = lambert(phi,i,l)
    plt.plot(phi/2/np.pi,modulation*on_off(phi,D)*flare + i,label=f"i={i/np.pi*180:.0f}" + r"$^{\circ}$",
            linewidth=2,)
    plt.plot(phi/2/np.pi,flare + i,c="grey",linestyle="dotted")
plt.title(f"bright flaring dot at different latitude {latdeg}" + r"$^{\circ}$",fontsize=15)
plt.xlabel("time [rotation periods]",fontsize=15)
plt.ylabel("flux",fontsize=15)
plt.legend(loc=(1.1,0),fontsize=15)
plt.xlim(0,3)
plt.tight_layout()
#plt.savefig(f"{CWD}/analysis/plots/model/rotating_bright_dot_flare.png",dpi=300)

# %% [markdown]
# # plot visibility as a function of day time

# %%
plt.figure(figsize=(12,4))
phi = np.linspace(0,6*np.pi,500) #(longitude)
daylengths = np.arange(.1,.91,.2)
for d in daylengths:
    plt.plot(phi/2/np.pi, on_off(phi,d), linewidth=d*2,c="k", label=f"day length / Prot={d:.1f}")
plt.legend(loc=(1.05,0))
plt.xlabel("time [days]")
plt.ylabel("visibility")
plt.tight_layout()
#plt.savefig(f"{CWD}/analysis/plots/model/visibility_vs_day.png",dpi=300)

# %% [markdown]
# # plot daylengths

# %%
I = np.linspace(0,np.pi/2,10)
L = np.linspace(-np.pi/2,np.pi/2, 500)[::-1]
plt.figure(figsize=(10,6))

    
for i in I:
    dl = []
    for l in L:
        dl.append(daylength(l,i))
    plt.plot(L/np.pi*180,dl,label=f"i={i/np.pi*180:.1f}")
plt.xlabel("latitude ",fontsize=15)
plt.ylabel("daylength",fontsize=15)
plt.ylim(-.1,1.1)
plt.xlim(-90,90)
plt.legend(loc=(1.1,0),fontsize=15)
plt.tight_layout()
#plt.savefig(f"{CWD}/analysis/plots/model/daylength.png",dpi=300)
